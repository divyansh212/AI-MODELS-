# %% [markdown]
# <a href="https://colab.research.google.com/github/divyansh212/AI-MODELS-/blob/main/Pytorch_p5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install  torchinfo

# %%
import torch
import torch.nn as nn

class neural_network(nn.Module):
  def __init__(self,num_features):
    super().__init__()
    self.linear=nn.Linear(num_features,1)
    self.sigmoid=nn.Sigmoid()
  def  forward(self,features):
    x=self.linear(features)#z=wx+bias
    x=self.sigmoid(x)#g(z)-->Activation fucntion
    return x
features=torch.rand(10,5)
model=neural_network(features.shape[1])
model(features)
# Out:
# tensor([[0.3706],
#         [0.4131],
#         [0.3839],
#         [0.3822],
#         [0.4134],
#         [0.4342],
#         [0.4130],
#         [0.3849],
#         [0.4158],
#         [0.4376]], grad_fn=<SigmoidBackward0>)
